# %%
import gym
from stable_baselines3 import PPO

# %%
env = gym.make('CartPole-v1')

model = PPO('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=10000)

obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
        obs = env.reset()
        
env.close()
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1354 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 980         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010425311 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -1.63e+03   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.15        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 46.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011720538 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | -73.2       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 35.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 920         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009179311 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.63       |
# |    explained_variance   | -3.21       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0186     |
# |    value_loss           | 48.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 908         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008743073 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | -0.659      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 55.9        |
# -----------------------------------------
